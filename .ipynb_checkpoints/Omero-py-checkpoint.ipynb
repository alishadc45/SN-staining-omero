# %%
import omero
from omero.gateway import BlitzGateway

print("OMERO erfolgreich geladen!")
# Out:
# OMERO erfolgreich geladen!

# %%
import sys
print(sys.executable)
# Out:
# /Users/alishadicarmine/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/bin/python

# %%
# Importiere das OMERO-Modul
import omero.gateway

# Verbinde dich zum OMERO-Server
conn = omero.gateway.BlitzGateway(
    username="DiCarmine",
    passwd="Leon1701!",
    host="134.76.18.202",
    port=4064,
)
connected = conn.connect()
print("Verbindung erfolgreich:", connected)
# Out:
# Verbindung erfolgreich: True

# %%
for project in conn.listProjects():
    print(f"Project: {project.getName()} (ID={project.getId()})")
# Out:
# ---------------------------------------------------------------------------
# ConnectionLostException                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for project in conn.listProjects():
#       2     print(f"Project: {project.getName()} (ID={project.getId()})")
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:3335, in _BlitzGateway.getObjects(self, obj_type, ids, params, attributes, respect_order, opts)
#    3332 query, params, wrapper = self.buildQuery(
#    3333     obj_type, ids, params, attributes, opts)
#    3334 qs = self.getQueryService()
# -> 3335 result = qs.findAllByQuery(query, params, self.SERVICE_OPTS)
#    3336 if respect_order and ids is not None:
#    3337     idMap = {}
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:5116, in ProxyObjectWrapper.__getattr__(self, attr)
#    5106 """
#    5107 Returns named attribute of the wrapped service.
#    5108 If attribute is a method, the method is wrapped to handle exceptions,
#    (...)   5113 :return:        Attribute or wrapped method
#    5114 """
#    5115 # safe call wrapper
# -> 5116 obj = self._obj or self._getObj()
#    5117 rv = getattr(obj, attr)
#    5118 if callable(rv):
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:5050, in ProxyObjectWrapper._getObj(self)
#    5048     except Ice.ConnectionLostException:
#    5049         logger.debug('... lost, reconnecting (_getObj)')
# -> 5050         self._connect()
#    5051         # self._obj = self._create_func()
#    5052 else:
#    5053     self._ping()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:4981, in ProxyObjectWrapper._connect(self, forcejoin)
#    4979 self._resyncConn(self._conn)
#    4980 logger.debug("proxy_connect: c")
# -> 4981 self._obj = self._create_func()
#    4982 logger.debug("proxy_connect: d")
#    4983 return True
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:5023, in ProxyObjectWrapper._resyncConn.<locals>.cf()
#    5019     return self._cast_to(
#    5020         self._conn.c.sf.getByName(self._service_name)
#    5021     )
#    5022 else:
# -> 5023     obj = getattr(self._conn.c.sf, self._func_str)()
#    5024     if isinstance(obj, omero.api.StatefulServiceInterfacePrx):
#    5025         conn._register_service(str(obj), traceback.extract_stack())
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero_API_ice.py:758, in ServiceFactoryPrx.getQueryService(self, _ctx)
#     757 def getQueryService(self, _ctx=None):
# --> 758     return _M_omero.api.ServiceFactory._op_getQueryService.invoke(self, ((), _ctx))
#
# ConnectionLostException: Ice.ConnectionLostException:
# recv() returned zero

# %%
print(conn.isConnected())
# Out:
# True

# %%
for project in conn.listProjects():
    print(f"Project: {project.getName()} (ID={project.getId()})")
# Out:
# ---------------------------------------------------------------------------
# ConnectionLostException                   Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for project in conn.listProjects():
#       2     print(f"Project: {project.getName()} (ID={project.getId()})")
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:3335, in _BlitzGateway.getObjects(self, obj_type, ids, params, attributes, respect_order, opts)
#    3332 query, params, wrapper = self.buildQuery(
#    3333     obj_type, ids, params, attributes, opts)
#    3334 qs = self.getQueryService()
# -> 3335 result = qs.findAllByQuery(query, params, self.SERVICE_OPTS)
#    3336 if respect_order and ids is not None:
#    3337     idMap = {}
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:5116, in ProxyObjectWrapper.__getattr__(self, attr)
#    5106 """
#    5107 Returns named attribute of the wrapped service.
#    5108 If attribute is a method, the method is wrapped to handle exceptions,
#    (...)   5113 :return:        Attribute or wrapped method
#    5114 """
#    5115 # safe call wrapper
# -> 5116 obj = self._obj or self._getObj()
#    5117 rv = getattr(obj, attr)
#    5118 if callable(rv):
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:5050, in ProxyObjectWrapper._getObj(self)
#    5048     except Ice.ConnectionLostException:
#    5049         logger.debug('... lost, reconnecting (_getObj)')
# -> 5050         self._connect()
#    5051         # self._obj = self._create_func()
#    5052 else:
#    5053     self._ping()
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:4981, in ProxyObjectWrapper._connect(self, forcejoin)
#    4979 self._resyncConn(self._conn)
#    4980 logger.debug("proxy_connect: c")
# -> 4981 self._obj = self._create_func()
#    4982 logger.debug("proxy_connect: d")
#    4983 return True
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero/gateway/__init__.py:5023, in ProxyObjectWrapper._resyncConn.<locals>.cf()
#    5019     return self._cast_to(
#    5020         self._conn.c.sf.getByName(self._service_name)
#    5021     )
#    5022 else:
# -> 5023     obj = getattr(self._conn.c.sf, self._func_str)()
#    5024     if isinstance(obj, omero.api.StatefulServiceInterfacePrx):
#    5025         conn._register_service(str(obj), traceback.extract_stack())
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Master Studium /Lab rot - Neuropatho/Week 5/Labrotation/env/lib/python3.11/site-packages/omero_API_ice.py:758, in ServiceFactoryPrx.getQueryService(self, _ctx)
#     757 def getQueryService(self, _ctx=None):
# --> 758     return _M_omero.api.ServiceFactory._op_getQueryService.invoke(self, ((), _ctx))
#
# ConnectionLostException: Ice.ConnectionLostException:
# recv() returned zero

# %%
if not conn.isConnected():
    conn.connect()

# %%
conn.close()
conn = BlitzGateway('DiCarmine', 'Leon1701!', host='134.76.18.202', port=4064)
conn.connect()
# Out:
# True

# %%
def connect_omero(max_retries=3, wait_sec=5):
    for attempt in range(max_retries):
        try:
            conn = BlitzGateway('DiCarmine', 'Leon1701!', host='134.76.18.20', port=4064)
            if not conn.connect():
                raise Exception("Verbindung fehlgeschlagen")
            print("Erfolgreich verbunden!")
            return conn
        except Exception as e:
            print(f"Verbindungsversuch {attempt + 1} fehlgeschlagen: {e}")
            time.sleep(wait_sec)
    raise ConnectionError("Konnte keine Verbindung zu OMERO herstellen.")

# %%
import omero.gateway

# Verbinde dich zum OMERO-Server
conn = omero.gateway.BlitzGateway(
    username="DiCarmine",
    passwd="Leon1701!",
    host="134.76.18.202",
    port=4064,
)
connected = conn.connect()
print("Verbindung erfolgreich:", connected)
# Out:
# Verbindung erfolgreich: True

# %%
def list_projects_safe(conn):
    try:
        projects = conn.listProjects()
        for project in projects:
            print(f"Project: {project.getName()} (ID={project.getId()})")
    except Exception as e:
        print(f"Fehler beim Zugriff auf Projekte: {e}")
        print("Versuche neu zu verbinden...")
        conn.close()
        conn = connect_omero()
        list_projects_safe(conn)

# %%
list_projects_safe(conn)
# Out:
# Project: Alzheimer Allgemein (ID=265)
# Project: Neuropatho Daten (ID=202)
# Project: CPM Oligo Story (ID=105)
# Project: SkalenMikroskop (ID=301)
# Project: CPM Astros (ID=377)
# Project: Alzheimer Spatial Statistics (ID=364)
# Project: AlzheimerTemp (ID=416)
# Project: RNAse (ID=449)
# Project: Alzheimer Franca (ID=704)
# Project: 250422 (ID=1002)
# Project: NG2_Olig2_test (ID=1054)
# Project: MS_Cortical_Autopsy (ID=1079)
# Project: MPG Biopsie (ID=1082)
# Project: RNAscope (ID=724)
# Project: LLC lesions (ID=845)
# Project: KontrollFälle (ID=846)
# Project: Alterskohorte (ID=874)
# Project: Austestungen (ID=904)
# Project: acute vs chronic EAE mice (ID=942)
# Project: FGF9 (ID=1129)
# Project: Aigli 20-8-2022 (ID=1114)
# Project: Aigli Project (ID=1117)
# Project: FFPE_single_cell (ID=1134)
# Project: Nafiye (ID=1152)
# Project: Dataset repeated (ID=1205)
# Project: Liquor (ID=1306)
# Project: C4d_CD project (ID=1308)
# Project: AD_Liesong (ID=1309)
# Project: FFPE_dissociation (ID=1310)
# Project: Visium (ID=1355)
# Project: Leukodystrophy (ID=1370)
# Project: CytAssist (ID=1421)
# Project: MS_Liesong (ID=1427)
# Project: Scan_26_09_2023 (ID=1455)
# Project: For Stefan (ID=1456)
# Project: B_2023_1040_TAF (ID=1466)
# Project: Diagnostik_Liquor_Scan (ID=2116)
# Project: TestCJD_Caro (ID=1487)
# Project: Clara (ID=1479)
# Project: Scans from Carlos (ID=1508)
# Project: Alzheimer_Inflammation (ID=1556)
# Project: MS_Proteom (ID=1562)
# Project: Aigli Vakrakou (ID=1564)
# Project: Mihaela_01_02_2024 (ID=1570)
# Project: Sonstiges (ID=1514)
# Project: C127_23_20 (ID=1580)
# Project: CB_revision (ID=1602)
# Project: 250324 (ID=1605)
# Project: Astrocytes (ID=1608)
# Project: BCAS_Revision (ID=1610)
# Project: RNAScope_HCR_FISH (ID=1652)
# Project: Franzi (ID=1654)
# Project: Thalamus Project (ID=1712)
# Project: Alzheimer Sariyu (ID=1718)
# Project: Xenium (ID=1725)
# Project: A_2024_15_14 (ID=1754)
# Project: Mihaela (ID=1939)
# Project: A_2022_12_12_EFI (ID=1992)
# Project: ADEM DM Patters (ID=2159)
# Project: |RNAseT2 (ID=1973)
# Project: Scanned_Luise (ID=1994)
# Project: Scan vom 11.2.25 (ID=2180)
# Project: scan vom 13.2.25 (ID=2181)
# Project: B462-25 (ID=2219)
# Project: Feten_NABC1_GPR17 (ID=2233)
# Project: TLR in Myositis (ID=2237)
# Project: B615-25 (ID=2251)
# Project: MS active lesions (ID=2252)
# Project: Bielschowsky (ID=2257)
# Project: CytAssistSupportImages (ID=2269)
# Project: NMO-scans mai 2025 (ID=2284)
# Project: TLR und Entzündung (ID=2306)
# Project: Jaekel (ID=2311)
# Project: Cell Culture (ID=2357)
# Project: Natalie (ID=2362)
# Project: Ameera (ID=2366)
# Project: cNMO Ancau (ID=2367)
# Project: zystic ms (ID=2368)
# Project: Expansion (ID=2371)
# Project: Omer (ID=2403)
# Project: TNFa Inhibitoren (ID=2405)
# Project: Aarathi (ID=2406)
# Project: Fatima_Rotation (ID=2407)
# Project: Natalia (ID=2410)
# Project: RNAscopeJonas (ID=2411)
# Project: BIEL_EFI (ID=2455)
# Project: schlecht Berka (ID=2459)

# %%
project_id = 1725
try:
    project = conn.getObject("Project", project_id)
    if project:
        print(f"Gefundenes Projekt: {project.getName()} (ID={project.getId()})")
    else:
        print(f"Projekt mit ID {project_id} existiert nicht oder ist nicht zugänglich.")
except Exception as e:
    print(f"Fehler beim Abrufen des Projekts: {e}")
# Out:
# Gefundenes Projekt: Xenium (ID=1725)

# %%
import omero.gateway

# Verbinde dich zum OMERO-Server
conn = omero.gateway.BlitzGateway(
    username="DiCarmine",
    passwd="Leon1701!",
    host="134.76.18.202",
    port=4064,
)
connected = conn.connect()
print("Verbindung erfolgreich:", connected)
# Out:
# Verbindung erfolgreich: True

# %%
project_id = 1725
project = conn.getObject("Project", project_id)

# Alle Datasets des Projekts auflisten
try:
    datasets = project.listChildren()  # gibt alle Datasets des Projekts zurück
    if datasets:
        for ds in datasets:
            print(f"Dataset: {ds.getName()} (ID={ds.getId()})")
    else:
        print("Keine Datasets in diesem Projekt gefunden.")
except Exception as e:
    print(f"Fehler beim Auflisten der Datasets: {e}")
# Out:
# Dataset: CTRL_SN_Sox9_Sox10 (ID=9516)
# Dataset: HEs (ID=9464)
# Dataset: RNAScope_Controls (ID=9336)
# Dataset: run_001 (ID=8352)
# Dataset: run_002 (ID=8680)
# Dataset: run_003 (ID=8944)
# Dataset: run_005 (ID=9274)
# Dataset: run_006 (ID=9349)
# Dataset: SN_CD8_CD163 (ID=9589)
# Dataset: SN_p53 (ID=9623)
# Dataset: SN_PD_Sox9_Sox10 (ID=9515)
# Dataset: Training_run (ID=7741)

# %%
# Bestimmtes Bild abrufen
dataset_id = 9589
dataset = conn.getObject("Dataset", dataset_id)

image_id = 366090

try:
    # Bild per ID abrufen
    image = conn.getObject("Image", image_id)
    
    # Optional: prüfen, ob Bild tatsächlich zu diesem Dataset gehört
    if image.getParent().getId() == dataset.getId():
        print(f"Gefundenes Bild: {image.getName()} (ID={image.getId()})")
    else:
        print("Dieses Bild gehört nicht zu diesem Dataset.")
except Exception as e:
    print(f"Fehler beim Abrufen des Bildes: {e}")
# Out:
# Gefundenes Bild: A_2017_80_7_CD8_DAB_CD163_FB.vsi [20x_BF_01] (ID=366090)

# %%
# to get pixel size
image_id = 366090
size_x = image.getPixelSizeX()       
print(" Pixel Size X:", size_x)
# Units support, new in OMERO 5.1.0
size_x_obj = image.getPixelSizeX(units=True)
print(" Pixel Size X:", size_x_obj.getValue(), "(%s)" % size_x_obj.getSymbol())
# To get the size with different units, e.g. Angstroms
size_x_ang = image.getPixelSizeX(units="ANGSTROM")
print(" Pixel Size X:", size_x_ang.getValue(), "(%s)" % size_x_ang.getSymbol())
# Out:
#  Pixel Size X: 0.27380993872196185
#  Pixel Size X: 0.27380993872196185 (µm)
#  Pixel Size X: 2738.0993872196186 (Å)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 20.9 MB/s eta 0:00:0031m22.0 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 kB 21.9 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp311-cp311-macosx_10_9_universal2.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 31.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in ./env/lib/python3.11/site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in ./env/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in ./env/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in ./env/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pyparsing-3.2.5
#
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from omero.gateway import BlitzGateway

conn = BlitzGateway("DiCarmine", "Leon1701!", host="134.76.18.202", port=4064)
conn.connect()
# Out:
# True

# %%
image_id = 366090
image = conn.getObject("Image", image_id)  # jetzt hast du ein echtes Image-Objekt
